# %% [markdown]
# ## fonte de dados

# %% [markdown]
# ### tvDataFeed

# %%
import pandas as pd
from datetime import datetime, timedelta
from tvDatafeed import TvDatafeed, Interval

# %%
username = 'carlos_py'
password = open('pass', 'r').read()

tv = TvDatafeed(username, password)
tv

# %%
tv.search_symbol('MGLU3')

# %%
df_intraday = tv.get_hist(symbol='MGLU3', interval=Interval.in_daily, exchange='BMFBOVESPA', n_bars=1000)
df_intraday

# %%
df_intraday['close'].plot()

# %% [markdown]
# ### yahoo finance

# %%
import yfinance as yf

# %%
petro = yf.download('PETR4.SA', start='2021-01-01')
petro
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker       PETR4.SA   PETR4.SA   PETR4.SA   PETR4.SA  PETR4.SA
# Date
# 2021-01-04   9.619958   9.709802   9.493511   9.533441  74719700
# 2021-01-05   9.995971  10.042556   9.397011   9.616629  95181100
# 2021-01-06  10.015936  10.282140   9.999298  10.035901  96562500
# 2021-01-07  10.315414  10.365328  10.095796  10.095796  56171300
# 2021-01-08  10.355346  10.568309  10.099124  10.468482  67136300
# ...               ...        ...        ...        ...       ...
# 2024-12-16  37.939999  38.259998  37.830002  38.189999  21349400
# 2024-12-17  38.299999  38.490002  37.830002  37.939999  39617200
# 2024-12-18  37.310001  38.400002  37.310001  38.279999  58126400
# 2024-12-19  37.160000  37.930000  36.980000  37.660000  43268400
# 2024-12-20  36.849998  37.349998  36.709999  37.160000  59277400
#
# [992 rows x 5 columns]

# %%
petr = yf.Ticker('PETR4.SA')
petr.info

# %%
petr.actions

# %%
petr.quarterly_financials

# %%
petr.major_holders

# %%
petr.balance_sheet
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                              104359669.0
# Preferred Shares Number                                     NaN
# Ordinary Shares Number                            12940137261.0
# Share Issued                                      13044496930.0
# Net Debt                                          16074000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  15546000000.0
# Other Short Term Investments                       2819000000.0
# Cash And Cash Equivalents                         12727000000.0
# Cash Equivalents                                  12624000000.0
# Cash Financial                                      103000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                                 295669.0
# Preferred Shares Number                                     NaN
# ...

# %%
petr.cashflow
# Out:
#                                             2023-12-31     2022-12-31  \
# Free Cash Flow                           31098000000.0  40136000000.0
# Repurchase Of Capital Stock               -735000000.0            0.0
# Repayment Of Debt                       -10479000000.0 -14764000000.0
# Issuance Of Debt                          2210000000.0   2880000000.0
# Capital Expenditure                     -12114000000.0  -9581000000.0
# ...                                                ...            ...
# Operating Gains Losses                    3049000000.0   4390000000.0
# Pension And Employee Benefit Expense      1542000000.0   1228000000.0
# Earnings Losses From Equity Investments    304000000.0   -251000000.0
# Net Foreign Currency Exchange Gain Loss   2498000000.0   4557000000.0
# Net Income From Continuing Operations    24995000000.0  36755000000.0
#
#                                             2021-12-31     2020-12-31  \
# ...

# %%
hist = petr.history(period='max')
hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   1.326403   1.326403   1.326403   1.326403
# 2000-01-04 00:00:00-02:00   1.253028   1.253028   1.253028   1.253028
# 2000-01-05 00:00:00-02:00   1.240384   1.240384   1.240384   1.240384
# 2000-01-06 00:00:00-02:00   1.236095   1.236095   1.236095   1.236095
# 2000-01-07 00:00:00-02:00   1.241738   1.241738   1.241738   1.241738
# ...                              ...        ...        ...        ...
# 2024-12-16 00:00:00-03:00  38.189999  38.259998  37.830002  37.939999
# 2024-12-17 00:00:00-03:00  37.939999  38.490002  37.830002  38.299999
# 2024-12-18 00:00:00-03:00  38.279999  38.400002  37.310001  37.310001
# 2024-12-19 00:00:00-03:00  37.660000  37.930000  36.980000  37.160000
# 2024-12-20 00:00:00-03:00  37.160000  37.349998  36.709999  36.849998
#
#                                 Volume  Dividends  Stock Splits
# Date
# ...
